# %% [markdown]
# # Introduction to Generative AI

# %% [markdown]
# Generative AI is a technology trained on very large datasets. It learns patterns in sequences of tokens (words, characters, and code symbols) and predicts what token is likely to come next. This lets it produce fluent text and plausible code from a prompt.

# %% [markdown]
# ## Limitations and Problems of Generative AI
#
# While generative AI models have many applications, they also have limitations.
#
# ### Correctness
#
# Generative AI models can produce incorrect or misleading content. This can be due to errors in the model, biases or incorrect information in the training data, or the limitations of the model architecture. This makes it vital to check the output of these models and not take it at face value. For example, I asked Copilot (which is powered by OpenAI's GPT-4) to solve a simple quadratic equation:
# <center>
# <img src="resources/quadratic_example.png" alt="Copilot failing to solve the quadratic equation" width="50%">
# </center>

# %% [markdown]
# It confidently provided an incorrect answer that appeared plausible at first glance. It provided the answers of $\frac{1}{2}$ and $-\frac{5}{4}$ when the correct answers were 0.804 and -1.55. The model does not understand the maths behind the problem and is simply generating text that looks like text one would see in a solution to a quadratic equation.
#
# When AIs imagine false information it is known as "hallucination".

# %% [markdown]
# ### Bias
#
# Generative AI models can also produce biased content. This is commonly due to biases in the training data, which can be reflected in the output of the model. For example, I asked Copilot for a list of the top 10 famous scientists and it provided the following list:
#
# * Albert Einstein
# * Isaac Newton
# * Nikola Tesla
# * Marie Curie
# * Niels Bohr
# * James Clerk Maxwell
# * Charles Darwin
# * Galileo Galilei
# * Rosalind Franklin
#
# This list is comprised entirely of Western scientists, with no representation from other parts of the world. This is an example of bias in the output of a generative AI model and probably occurs because the internet has more information about Western scientists than scientists from other parts of the world.

# %% [markdown]
# ### Easy to Confuse
#
# Generative AI can be misled by incorrect or ambiguous prompts. For example, I asked Copilot what the westernmost point of Europe was, and contradicted its answer:
#
# <center>
# <img src="resources/western_europe_example.png" alt="Arguing with AI over the westernmost point of Europe" width="50%">
# </center>

# %% [markdown]
# Copilot was not confident enough in its original correct answer and changed it to a different answer when I contradicted it. This means that, if you push an AI in particular direction, deliberately or accidentally, it may provide incorrect information.

# %% [markdown]
# ### Environmental Impact
#
# Training and running generative AI models requires substantial computational resources, including electricity and water. This contributes to carbon emissions and resource use.
#
# ### Cost
#
# Generative AI models are expensive to train and run. Users are often billed by token usage, so cost increases with longer prompts, longer outputs, and additional model reasoning.
#
# ### Data Security and Privacy
#
# Different providers have different policies for how your prompts and files are stored and reused. Some may use submitted data to improve their models. This could resurface information you put into the model in other users' outputs. You should be aware of the data security and privacy policies of any generative AI tools you use, and avoid putting sensitive information into them.
#
# **Practical rule: never paste identifiable, confidential, or otherwise sensitive data into public or externally hosted AI tools.**
#
# This is especially important for:
#
# * Patient data
# * Proprietary data
# * Personal data
# * Confidential information from government or commercial organisations
#
# ### Academic Integrity
#
# You should be aware of the rules surrounding the use of generative AI in your academic work and submissions. At Imperial, you should not submit work that you did not produce (including material produced by generative AI tools) for academic credit without proper citation, or unless the use of such tools is explicitly permitted in the assignment or submission.
#
# If you want to know more about Imperial's rules and guidance on generative AI, there is general guidance [here](https://www.imperial.ac.uk/students/academic-support/ai-and-study-guidance-hub/) and  advice from the library on how to reference your use of generative AI tools [here](https://www.imperial.ac.uk/admin-services/library/learning-support/generative-ai-guidance/).
#
# Some journals also have policies regarding the use of generative AI in research papers. Before submitting to a journal, check their policies to ensure you are complying with their rules

# %% [markdown]
# ### Intellectual Property
#
# Generative AI may be used to infringe on intellectual property rights, such as copyright or trademarks. Models may have been trained on copyrighted data, or may generate content that infringes on existing intellectual property. This can viewed as a form of stealing and can damage the livelihoods of creators.
#
# ### Misrepresentation
#
# Generative AI models make it easier to create a dishonest representation of a person's abilities or knowledge. For example, a job applicant could use a generative AI model to generate a fake portfolio of work, or answer to interview questions.
#
# ### Contamination of the Scientific Record
#
# Incorporation of content produced by generative AI models into research publications risks the introduction of hallucinations and mistakes into the scientific record. This could hamper the progress of science in the long-term.

# %% [markdown]
# ## Generative AI and Programming
#
# That makes it useful for programming, but it also comes with important limitations. Some considerations are summarised below:
#
# * **Generative AI can produce useful information on many topics**: Models are trained on broad datasets, so they can often give helpful answers quickly. However, generative AI can give entirely incorrect or fictitious arguments with convincing confidence.
# * **Generative AI is fast**: It can generate drafts, examples, and code much faster than most people can write from scratch.
# * **Generative AI does not think like a human**: It has no understanding or consciousness. It generates output from statistical patterns, so it may make cognitive leaps people would not, and also mistakes people would not.
# * **Generative AI is not always correct**: Generative AI models can produce plausible-looking code with subtle bugs, missing edge cases, or incorrect assumptions.
# * **Generative AI has limited working memory**: It relies on a finite "context window". In long tasks, it can lose track of earlier details and become inconsistent.
#
# The key consequence is that generative AI can be a powerful programming partner, but it needs active human oversight. You should critically evaluate outputs and verify correctness.
#
# Tasks that generative AI tends to perform poorly at include:
#
# * Keeping track of the overall project goal over long periods
# * Relating code decisions to a specific research or real-world context
# * Choosing which behaviours and edge cases matter most in your context
# * Judging when to refactor or reorganise code
# * Planning what to do next in larger projects
# * Retaining long-term context across many iterations
# * Simplifying code by deleting or combining parts (it often adds more than it removes)
#
# These are responsibilities that should stay with you. For focused tasks, such as drafting a function or making a small feature change, AI can accelerate your work, but only with careful steering and review.
